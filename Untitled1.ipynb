# %%
#此cell为最终程序，下面的三个cell是单独测试功能与准备的cell，第一个是测试邮件功能，第二个是测试绘图功能，第三个为此cell准备必要数据


from time import sleep, strftime
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.header import Header


#全局变量
Preferential=[]
flight_list=[]
password=0#检查输入是否异常
date_out_=[]
city_out_=[]
city_to_=[]
date_to_=[]
f_payi=[]

#填入chromedriver的路径，一般在C:\Program Files (x86)\Google\Chrome\Application\,如果没有需下载
chromedriver_path = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
driver = webdriver.Chrome(executable_path=chromedriver_path) # 打开chrome窗口



#翻到下一个页面
def next_click_botton(number):
    cheap_paice='//*[@data-ubt="c_calendar_banner_'+str(number)+'"]'
    driver.find_element_by_xpath(cheap_paice).click()
    print('页面'+str(number)+'加载中.........')
    sleep(4)#防止因为网速问题而产生无法定位元素的错误
    #测试是否成功点击
    #strtest=driver.find_element_by_xpath('//*[@class="calendar_date"]').text
    #print(strtest)

    
    
    
#获取当前页面的初始数据
def web_result():
    try:
        result_k='//*[@class="search_table_header"]'#选择xpath时请不要复制
        #result_k='//*[@class="cabinV2"]'
        result_k_contain=driver.find_elements_by_xpath(result_k)
        print('正在读取页面数据.........')#信息交互让用户知道程序正在流畅运行
    except NoSuchElementException:
        print('由于网速问题使访问过慢，程序出错')
        pass
    result_k_list=[]
    result_k_split0=[]
    for result in result_k_contain:
        result_k_list.append(result.text)
    for result in result_k_list:
        result_k_split0.append(result.split('\n'))
    #print(result_k_split0)
    return result_k_split0#获得基本数据


#整理数据
def re_result():
    global f_payi
    print('处理数据中')
    global flight_list
    f_tot=[]
    f_outt=[]
    f_g=[]
    f_x=[]
    f_outf=[]
    f_tof=[]
    f_z=[]
    f_k=[]
    f_q=[]
    for a in flight_list:
        for aa in a:
            if aa[8]!='订立减¥3' and aa[8]!='准点率' and aa[8]!='订立减¥5':
                f_g.append(aa[0])
                f_x.append(aa[1])
                f_outt.append(aa[2])
                f_outf.append(aa[3])
                f_tot.append(aa[4])
                f_tof.append(aa[5])
                f_z.append(aa[7])
                f_q.append(int(aa[8][1:4]))
                #在统计数据时随便找最便宜的机票
                if(int(f_payi1[8][1:4])>int(aa[8][1:4])):
                    f_payi1=aa
                f_k.append(aa[9])
            elif aa[8]=='订立减¥3':
                f_g.append(aa[0])
                f_x.append(aa[1])
                f_outt.append(aa[2])
                f_outf.append(aa[3])
                f_tot.append(aa[4])
                f_tof.append(aa[5])
                f_z.append(aa[7])
                f_q.append(int(aa[9][1:4]))
                #在统计数据时随便找最便宜的机票
                if(int(f_payi2[9][1:4])>int(aa[9][1:4])):
                    f_payi2=aa
                f_k.append(aa[10])
            elif aa[8]=='订立减¥5':
                f_g.append(aa[0])
                f_x.append(aa[1])
                f_outt.append(aa[2])
                f_outf.append(aa[3])
                f_tot.append(aa[4])
                f_tof.append(aa[5])
                f_z.append(aa[7])
                f_q.append(int(aa[9][1:4]))
                #在统计数据时随便找最便宜的机票
                if(int(f_payi2[9][1:4])>int(aa[9][1:4])):
                    f_payi2=aa
                f_k.append(aa[10]) 
            else:
                f_g.append(aa[0])
                f_x.append(aa[1])
                f_outt.append(aa[2])
                f_outf.append(aa[3])
                f_tot.append(aa[6])
                f_tof.append(aa[7])
                f_z.append(aa[9])
                try:
                    f_q.append(int(aa[10][1:4]))
                except ValueError:
                    print(aa)
                    driver.quit()
                #在统计数据时随便找最便宜的机票
                if(int(f_payi3[10][1:4])>int(aa[10][1:4])):
                    f_payi3=aa
                f_k.append(aa[11])
    if(int(f_payi1[8][1:4])<int(f_payi2[9][1:4])):
        f_payi=f_payi1
        if(int(f_payi1[8][1:4])>int(f_payi3[10][1:4])):
            f_payi=_f_payi3
    elif(int(f_payi2[9][1:4])<int(f_payi3[10][1:4])):
        f_payi=f_payi2
    else:
        f_payi=f_payi3
    #出现pd用无法显示中文问题，改为英文
    flights_df = pd.DataFrame({'Airline company|': f_g,
                           'Aircraft model|':f_x,
                           'Out Early Day|': f_outt,
                           'Out Duration|': f_outf,
                           'Out Later Day|': f_tot,
                           'To Duration|': f_tof,
                           'Aircraft model|':f_z,
                           'Price|':f_q,
                           'Preferentail':f_k,
                          })
    flights_df['timestamp'] = strftime("%Y%m%d-%H%M")
    return flights_df



def Cmail():
    global f_payi
    global date_to_
    global date_out_
    global city_to_
    global city_out_
    final_df=re_result()
    final_df.to_excel(r'C:\Users\user\Music//{}_flights_{}-{}__{}_to_{}.xlsx'.format(strftime("%Y%m%d-%H%M"),city_out_, city_to_, date_out_, date_to_), index=False)
    print('保存表格.....')
    f_payi0=[str(i) for i in f_payi]#将列表变为字符串，方面发送
    f_payi4=' '.join(f_payi0)
    from_addr=input('发信邮箱（最好为QQ邮箱，例：1719913794@qq.com')
    to_addr=input('收信邮箱（最好为QQ邮箱，例：1719913794@qq.com')
    smtp_server=input('邮箱服务器，若为QQ邮箱则为smtp.qq.com')
    pwd=input('密钥，需要查询例：kqjapjuxnoxeefbb')
    mail_content='测试'
    mail_title='测试邮件'
    # 邮件对象:
    msg = MIMEMultipart()
    msg['From'] = from_addr
    msg['To'] =Header("接受测试",'utf-8')
    msg['Subject'] = Header(mail_title, 'utf-8')

    # 邮件正文是MIMEText:
    msg.attach(MIMEText('send with file...'+'\n'+f_payi4, 'html', 'utf-8'))
    # 构造附件，传送当前目录下的 文件
    att1 = MIMEText(open(r'C:\Users\user\Music//{}_flights_{}-{}__{}_to_{}.xlsx'.format(strftime("%Y%m%d-%H%M"),city_out_, city_to_, date_out_, date_to_), 'rb').read(), 'base64', 'utf-8')
    att1["Content-Type"] = 'application/octet-stream'
    # 这里的filename可以任意写，写什么名字，邮件中显示什么名字
    att1["Content-Disposition"] = 'attachment; filename="www.xlsx"'
    msg.attach(att1)
    #ssl登录
    smtp = SMTP_SSL(smtp_server)
    #set_debuglevel()是用来调试的。参数值为1表示开启调试模式，参数值为0关闭调试模式
    smtp.set_debuglevel(1)
    smtp.ehlo(smtp_server)
    smtp.login(from_addr, pwd)
    print('正在发送邮件')
    smtp.sendmail(from_addr, to_addr, msg.as_string())
    smtp.quit()
    plt.title("time-paice")
    plt.scatter(f_outt,f_q)
    fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))
    vert_bars = axes[0].barh(f_outt, f_q, color='#9999ff', align='center')
    horiz_bars = axes[1].barh(f_outt, f_z, color='#ff9999', align='center')
    #在水平或者垂直方向上画线
    axes[0].axvline(0, color='gray', linewidth=2)
    axes[1].axvline(0, color='gray', linewidth=2)
    plt.rcParams['savefig.dpi'] = 500 #图片像素
    plt.rcParams['figure.dpi'] = 500 #分辨率
    plt.show()

#打开网页
def web_open(date_out,city_out,city_to,date_return):
    global password#赋值操作是局部的，所以对全局变量进行修改时需要声明
    kayakURL='https://flights.ctrip.com/itinerary/oneway/'+city_out+'-'+city_to+'?date='+date_out
    try:
        driver.get(kayakURL)
        print('正在打开页面，请勿对打开的浏览器进行任何操作')
    except:
        print('\n警告！！！时间输入错误\n')
        password=1
        return
    sleep(randint(4,8))

    
    
#搜索城市的id
def cityid_search(cityname):
    global password#赋值操作是局部的，所以对全局变量进行修改时需要声明
    data0=open('XC_data.txt','r')
    data1=data0.read()
    data0.close()
    data2=data1.split(')\n')#特征信息是：城市（城市对应的字母）\n
    data3=[]
    for dd in data2:
        data3.append(dd.split('('))#对每个城市通过')'进行分割
    data6={}
    for dd in data3:   
        data6.update({dd[0]:dd[1]})
    data6['遵义']='ZYI'#最后的括号没有\n，单独拿出修改
    try:
        data7=data6[cityname]
    except KeyError:
        print("\n警告！！！所输入城市错误或当地没有机场\n")
        password=1
        return 0
    return data7

    
    
#用户交互函数
def putinit():
    global password#赋值操作是局部的，所以对全局变量进行修改时需要声明
    print('网页加载中不可对页面进行任何操作，否则会使程序出错')
    city_out=cityid_search(input("请输入起点城市名称（注：若想同一城市不同机场出发，请用‘[]’进行注释，例：北京[南苑机场]）"))
    city_to=cityid_search(input("请输入终点城市名称（注：若想同一城市不同机场出发，请用‘[]’进行注释，例：北京[南苑机场]）"))
    if(password==1):
        return
    date_out=input("请输入可选出发时间的最早日期（例：2019-07-18）")
    date_return=input("请输入可选出发时间的最晚日期（例：2019-07-21）")
    date_out_=date_out
    city_out_=city_out
    city_to_=city_to
    date_to_=date_return
    web_open(date_out,city_out,city_to,date_return)
    if(password==1):
        return
    date_out=date_out.split('-')
    date_to=date_return.split('-')
    return [date_out,date_to]



date_list=putinit()
if(password==0):
    for number in range(int(date_list[0][2]),int(date_list[1][2])+1):
        flight_list.append(web_result())
        next_click_botton(number)
    print('程序读取完毕')
    Cmail()
    driver.quit()
else:
    driver.quit()
#对数据进行pd表格管理，写三层for循环，在循环时统计当前最低价
# Out:
# 网页加载中不可对页面进行任何操作，否则会使程序出错
# 请输入起点城市名称（注：若想同一城市不同机场出发，请用‘[]’进行注释，例：北京[南苑机场]）北京
# 请输入终点城市名称（注：若想同一城市不同机场出发，请用‘[]’进行注释，例：北京[南苑机场]）上海
# 请输入可选出发时间的最早日期（例：2019-07-18）2019-07-18
# 请输入可选出发时间的最晚日期（例：2019-07-21）2019-07-22
# 正在打开页面，请勿对打开的浏览器进行任何操作
# 正在读取页面数据.........
# 页面18加载中.........
# 正在读取页面数据.........
# 页面19加载中.........
# 正在读取页面数据.........
# 页面20加载中.........
# 正在读取页面数据.........
# 页面21加载中.........
# 正在读取页面数据.........
# 页面22加载中.........
# 程序读取完毕
# 处理数据中
# 保存表格.....
# send: 'ehlo smtp.qq.com\r\n'
# reply: b'250-smtp.qq.com\r\n'
# reply: b'250-PIPELINING\r\n'
# reply: b'250-SIZE 73400320\r\n'
# reply: b'250-AUTH LOGIN PLAIN\r\n'
# reply: b'250-AUTH=LOGIN\r\n'
# reply: b'250-MAILCOMPRESS\r\n'
# reply: b'250 8BITMIME\r\n'
# reply: retcode (250); Msg: b'smtp.qq.com\nPIPELINING\nSIZE 73400320\nAUTH LOGIN PLAIN\nAUTH=LOGIN\nMAILCOMPRESS\n8BITMIME'
# send: 'AUTH PLAIN ADE3MTk5MTM3OTRAcXEuY29tAGtxamFwanV4bm94ZWVmYmI=\r\n'
# reply: b'235 Authentication successful\r\n'
# ...

# %%
#测试邮箱功能

from time import sleep, strftime
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import smtplib
from email.mime.text import MIMEText
from email.header import Header
from smtplib import SMTP_SSL
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.header import Header
f_tot=[]
f_outt=[]
f_g=[]
f_x=[]
f_outf=[]
f_tof=[]
f_z=[]
f_k=[]
f_q=[]
flight=[[['中国联航KN5737', '波音 737-800(中型)', '07:50', '南苑机场', '09:50', '虹桥国际机场T2', '准点率', '70%', '¥532起', '经济舱3.6折', '订票'], ['海南航空HU7611', '波音 787-9(大型)', '07:40', '首都国际机场T1', '09:55', '浦东国际机场T2', '准点率', '83%', '订立减¥3', '¥625起', '经济舱4.2折', '订票'], ['海南航空HU7605', '波音 787-9(大型)', '07:45', '首都国际机场T1', '10:00', '虹桥国际机场T2', '准点率', '87%', '订立减¥3', '¥625起', '经济舱4.2折', '订票'], ['东方航空MU5156', '空中客车 A330(大型)', '08:30', '首都国际机场T2', '10:40', '虹桥国际机场T2', '准点率', '77%', '¥640起', '经济舱4.3折', '订票'], ['东方航空MU5138', '空中客车 A330(大型)', '07:00', '首都国际机场T2', '09:20', '虹桥国际机场T2', '准点率', '97%', '¥670起', '经济舱4.5折', '订票'], ['东方航空MU5183', '空中客车 A321(中型)', '07:35', '首都国际机场T2', '09:50', '浦东国际机场T1', '准点率', '93%', '¥670起', '经济舱4.5折', '订票'], ['东方航空MU5390', '空中客车 A321(中型)', '13:10', '首都国际机场T2', '经停', '洛阳', '18:10', '虹桥国际机场T2', '准点率', '90%', '¥670起', '经济舱4.5折', '订票'], ['中国联航KN5977', '波音 737(中型)', '11:55', '南苑机场', '14:05', '浦东国际机场T1', '准点率', '67%', '¥753起', '经济舱5.1折', '订票'], ['中国联航KN5987', '波音 737(中型)', '19:20', '南苑机场', '21:30', '浦东国际机场T1', '准点率', '80%', '¥753起', '经济舱5.1折', '订票'], ['中国联航KN5955', '波音 737(中型)', '15:40', '南苑机场', '17:40', '虹桥国际机场T2', '准点率', '67%', '¥765起', '经济舱5.2折', '订票'], ['吉祥航空HO1252', '空中客车 A321(中型)', '06:50', '首都国际机场T3', '09:05', '虹桥国际机场T2', '准点率', '-', '¥770起', '经济舱5.2折', '订票'], ['东方航空MU5104', '空中客车 A330(大型)', '09:00', '首都国际机场T2', '11:15', '虹桥国际机场T2', '准点率', '73%', '¥790起', '经济舱5.4折', '订票'], ['海南航空HU7607', '波音787-9(大型)', '08:45', '首都国际机场T1', '11:00', '虹桥国际机场T2', '准点率', '73%', '订立减¥3', '¥795起', '经济舱5.4折', '订票'], ['东方航空MU5102', '空中客车 A330-300(大型)', '08:00', '首都国际机场T2', '10:15', '虹桥国际机场T2', '准点率', '80%', '¥830起', '经济舱5.6折', '订票'], ['厦门航空MF3018共享', '波音 737-800(中型)', '21:30', '首都国际机场T2', '23:45', '虹桥国际机场T2', '准点率', '72%', '¥830起', '经济舱6.7折', '订票'], ['东方航空MU5158', '波音 737-800(中型)', '21:30', '首都国际机场T2', '23:45', '虹桥国际机场T2', '准点率', '72%', '¥830起', '经济舱5.6折', '订票']], [['中国联航KN5737', '波音 737-800(中型)', '07:50', '南苑机场', '09:50', '虹桥国际机场T2', '准点率', '70%', '¥603起', '经济舱4.1折', '订票'], ['海南航空HU7611', '波音 787-9(大型)', '07:40', '首都国际机场T1', '09:55', '浦东国际机场T2', '准点率', '83%', '订立减¥3', '¥625起', '经济舱4.2折', '订票'], ['海南航空HU7605', '波音 787-9(大型)', '07:45', '首都国际机场T1', '10:00', '虹桥国际机场T2', '准点率', '87%', '订立减¥3', '¥625起', '经济舱4.2折', '订票'], ['东方航空MU5138', '空中客车 A330(大型)', '07:00', '首都国际机场T2', '09:20', '虹桥国际机场T2', '准点率', '97%', '¥670起', '经济舱4.5折', '订票'], ['东方航空MU5183', '空中客车 A321(中型)', '07:35', '首都国际机场T2', '09:50', '浦东国际机场T1', '准点率', '93%', '¥670起', '经济舱4.5折', '订票'], ['海南航空HU7607', '空中客车 A330-300(大型)', '08:45', '首都国际机场T1', '11:00', '虹桥国际机场T2', '准点率', '73%', '订立减¥3', '¥715起', '经济舱4.8折', '订票'], ['吉祥航空HO1252', '空中客车 A321(中型)', '06:50', '首都国际机场T3', '09:05', '虹桥国际机场T2', '准点率', '-', '¥770起', '经济舱5.2折', '订票'], ['东方航空MU5156', '空中客车 A330(大型)', '08:30', '首都国际机场T2', '10:40', '虹桥国际机场T2', '准点率', '77%', '�
', '订票'], ['东方航空MU5104', '空中客车 A330(大型)', '09:00', '首都国际机场T2', '11:15', '虹桥国际机场T2', '准点率', '73%', '¥790起', '经济舱5.4折', '订票'], ['海南航空HU7607', '波音787-9(大型)', '08:45', '首都国际机场T1', '11:00', '虹桥国际机场T2', '准点率', '77%', '订立减¥3', '¥795起', '经济舱5.4折', '订票'], ['东方航空MU5102', '空中客车 A330-200(大型)', '08:00', '首都国际机场T2', '10:15', '虹桥国际机场T2', '准点率', '80%', '¥830起', '经济舱5.6折', '订票'], ['厦门航空MF3018共享', '空中客车 A330-200(大型)', '21:30', '首都国际机场T2', '23:45', '虹桥国际机场T2', '准点率', '72%', '¥830起', '经济舱6.7折', '订票'], ['东方航空MU5158', '空中客车 A330-200(大型)', '21:30', '首都国际机场T2', '23:45', '虹桥国际机场T2', '准点率', '72%', '¥830起', '经济舱5.6折', '订票'], ['东方航空MU5160', '空中客车 A330-300(大型)', '21:50', '首都国际机场T2', '23:55', '虹桥国际机场T2', '准点率', '63%', '¥830起', '经济舱5.6折', '订票']]]
for a in flight:
    for aa in a:
        if aa[8]!='订立减¥3' and aa[8]!='准点率':
            f_g.append(aa[0])
            f_x.append(aa[1])
            f_outt.append(aa[2])
            f_outf.append(aa[3])
            f_tot.append(aa[4])
            f_tof.append(aa[5])
            f_z.append(aa[7])
            f_q.append(int(aa[8][1:4]))
            f_k.append(aa[9])
        elif aa[8]=='订立减¥3':
            f_g.append(aa[0])
            f_x.append(aa[1])
            f_outt.append(aa[2])
            f_outf.append(aa[3])
            f_tot.append(aa[4])
            f_tof.append(aa[5])
            f_z.append(aa[7])
            f_q.append(int(aa[9][1:4]))
            f_k.append(aa[10])
        else:
            f_g.append(aa[0])
            f_x.append(aa[1])
            f_outt.append(aa[2])
            f_outf.append(aa[3])
            f_tot.append(aa[6])
            f_tof.append(aa[7])
            f_z.append(aa[9])
            f_q.append(int(aa[10][1:4]))
            f_k.append(aa[11])

f_payi1=['中国联航KN5737', '波音 737-800(中型)', '07:50', '南苑机场', '09:50', '虹桥国际机场T2', '准点率', '70%', '¥520起', '经济舱3.6折', '订票']
#出现pd用无法显示中文问题，改为英文
flights_df = pd.DataFrame({'Airline company|': f_g,
                           'Aircraft model|':f_x,
                           'Out Early Day|': f_outt,
                           'Out Duration|': f_outf,
                           'Out Later Day|': f_tot,
                           'To Duration|': f_tof,
                           'Aircraft model|':f_z,
                           'Price|':f_q,
                           'Preferentail':f_k,
                          })
city_out_=1
city_to_=1
date_out_=1
date_to_=1
f_payi0=[str(i) for i in f_payi1]
f_payi4=' '.join(f_payi0)
flights_df['timestamp'] = strftime("%Y%m%d-%H%M")
final_df=flights_df
#文件名中的 \U 开始的字符被编译器认为是八进制
final_df.to_excel(r'C:\Users\user\Music//{}_flights_{}-{}__{}_to_{}.xlsx'.format(strftime("%Y%m%d-%H%M"),city_out_, city_to_, date_out_, date_to_), index=False)
print('保存表格.....')
from_addr='1719913794@qq.com'
to_addr='1719913794@qq.com'
smtp_server='smtp.qq.com'
pwd='kqjapjuxnoxeefbb'
mail_content='测试'
mail_title='测试邮件'
# 邮件对象:
msg = MIMEMultipart()
msg['From'] = from_addr
msg['To'] =Header("接受测试",'utf-8')
msg['Subject'] = Header(mail_title, 'utf-8')

# 邮件正文是MIMEText:
msg.attach(MIMEText('send with file...'+'\n'+f_payi4, 'html', 'utf-8'))
# 构造附件1，传送当前目录下的 test.txt 文件
att1 = MIMEText(open(r'C:\Users\user\Music//{}_flights_{}-{}__{}_to_{}.xlsx'.format(strftime("%Y%m%d-%H%M"),city_out_, city_to_, date_out_, date_to_), 'rb').read(), 'base64', 'utf-8')
att1["Content-Type"] = 'application/octet-stream'
# 这里的filename可以任意写，写什么名字，邮件中显示什么名字
att1["Content-Disposition"] = 'attachment; filename="www.xlsx"'
msg.attach(att1)
#ssl登录
smtp = SMTP_SSL(smtp_server)
#set_debuglevel()是用来调试的。参数值为1表示开启调试模式，参数值为0关闭调试模式
smtp.set_debuglevel(1)
smtp.ehlo(smtp_server)
smtp.login(from_addr, pwd)

smtp.sendmail(from_addr, to_addr, msg.as_string())
smtp.quit()
# Out:
# 保存表格.....
# send: 'ehlo smtp.qq.com\r\n'
# reply: b'250-smtp.qq.com\r\n'
# reply: b'250-PIPELINING\r\n'
# reply: b'250-SIZE 73400320\r\n'
# reply: b'250-AUTH LOGIN PLAIN\r\n'
# reply: b'250-AUTH=LOGIN\r\n'
# reply: b'250-MAILCOMPRESS\r\n'
# reply: b'250 8BITMIME\r\n'
# reply: retcode (250); Msg: b'smtp.qq.com\nPIPELINING\nSIZE 73400320\nAUTH LOGIN PLAIN\nAUTH=LOGIN\nMAILCOMPRESS\n8BITMIME'
# send: 'AUTH PLAIN ADE3MTk5MTM3OTRAcXEuY29tAGtxamFwanV4bm94ZWVmYmI=\r\n'
# reply: b'235 Authentication successful\r\n'
# reply: retcode (235); Msg: b'Authentication successful'
# send: 'mail FROM:<1719913794@qq.com> size=15101\r\n'
# reply: b'250 Ok\r\n'
# reply: retcode (250); Msg: b'Ok'
# send: 'rcpt TO:<1719913794@qq.com>\r\n'
# reply: b'250 Ok\r\n'
# reply: retcode (250); Msg: b'Ok'
# send: 'data\r\n'
# reply: b'354 End data with <CR><LF>.<CR><LF>\r\n'
# reply: retcode (354); Msg: b'End data with <CR><LF>.<CR><LF>'
# data: (354, b'End data with <CR><LF>.<CR><LF>')
# ...

# %%
#测试绘图功能

from time import sleep, strftime
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import numpy as np 
import matplotlib.pyplot as plt 
f_tot=[]
f_outt=[]
f_g=[]
f_x=[]
f_outf=[]
f_tof=[]
f_z=[]
f_k=[]
f_q=[]
f_payi1=['中国联航KN5737', '波音 737-800(中型)', '07:50', '南苑机场', '09:50', '虹桥国际机场T2', '准点率', '70%', '¥999起', '经济舱3.6折', '订票']
f_payi2=['海南航空HU7605', '波音 787-9(大型)', '07:45', '首都国际机场T1', '10:00', '虹桥国际机场T2', '准点率', '87%', '订立减¥3', '¥625起', '经济舱4.2折', '订票']
f_payi3=['','','','','','','','','','','w999w','','','','']
flight=[[['中国联航KN5737', '波音 737-800(中型)', '07:50', '南苑机场', '09:50', '虹桥国际机场T2', '准点率', '70%', '¥532起', '经济舱3.6折', '订票'], ['海南航空HU7611', '波音 787-9(大型)', '07:40', '首都国际机场T1', '09:55', '浦东国际机场T2', '准点率', '83%', '订立减¥3', '¥625起', '经济舱4.2折', '订票'], ['海南航空HU7605', '波音 787-9(大型)', '07:45', '首都国际机场T1', '10:00', '虹桥国际机场T2', '准点率', '87%', '订立减¥3', '¥625起', '经济舱4.2折', '订票'], ['东方航空MU5156', '空中客车 A330(大型)', '08:30', '首都国际机场T2', '10:40', '虹桥国际机场T2', '准点率', '77%', '¥640起', '经济舱4.3折', '订票'], ['东方航空MU5138', '空中客车 A330(大型)', '07:00', '首都国际机场T2', '09:20', '虹桥国际机场T2', '准点率', '97%', '¥670起', '经济舱4.5折', '订票'], ['东方航空MU5183', '空中客车 A321(中型)', '07:35', '首都国际机场T2', '09:50', '浦东国际机场T1', '准点率', '93%', '¥670起', '经济舱4.5折', '订票'], ['东方航空MU5390', '空中客车 A321(中型)', '13:10', '首都国际机场T2', '经停', '洛阳', '18:10', '虹桥国际机场T2', '准点率', '90%', '¥670起', '经济舱4.5折', '订票'], ['中国联航KN5977', '波音 737(中型)', '11:55', '南苑机场', '14:05', '浦东国际机场T1', '准点率', '67%', '¥753起', '经济舱5.1折', '订票'], ['中国联航KN5987', '波音 737(中型)', '19:20', '南苑机场', '21:30', '浦东国际机场T1', '准点率', '80%', '¥753起', '经济舱5.1折', '订票'], ['中国联航KN5955', '波音 737(中型)', '15:40', '南苑机场', '17:40', '虹桥国际机场T2', '准点率', '67%', '¥765起', '经济舱5.2折', '订票'], ['吉祥航空HO1252', '空中客车 A321(中型)', '06:50', '首都国际机场T3', '09:05', '虹桥国际机场T2', '准点率', '-', '¥770起', '经济舱5.2折', '订票'], ['东方航空MU5104', '空中客车 A330(大型)', '09:00', '首都国际机场T2', '11:15', '虹桥国际机场T2', '准点率',
            f_outt.append(aa[2])
            f_outf.append(aa[3])
            f_tot.append(aa[4])
            f_tof.append(aa[5])
            f_z.append(aa[7])
            f_q.append(int(aa[8][1:4]))
            if(int(f_payi1[8][1:4])>int(aa[8][1:4])):
                f_payi1=aa
            f_k.append(aa[9])
        elif aa[8]=='订立减¥3':
            f_g.append(aa[0])
            f_x.append(aa[1])
            f_outt.append(aa[2])
            f_outf.append(aa[3])
            f_tot.append(aa[4])
            f_tof.append(aa[5])
            f_z.append(aa[7])
            f_q.append(int(aa[9][1:4]))
            if(int(f_payi2[9][1:4])>int(aa[9][1:4])):
                f_payi2=aa
            f_k.append(aa[10])
        else:
            f_g.append(aa[0])
            f_x.append(aa[1])
            f_outt.append(aa[2])
            f_outf.append(aa[3])
            f_tot.append(aa[6])
            f_tof.append(aa[7])
            f_z.append(aa[9])
            f_q.append(int(aa[10][1:4]))
            if(int(f_payi3[10][1:4])>int(aa[10][1:4])):
                f_payi3=aa
            f_k.append(aa[11])
f_payi=[]
if(int(f_payi1[8][1:4])<int(f_payi2[9][1:4])):
    f_payi=f_payi1
    if(int(f_payi1[8][1:4])>int(f_payi3[10][1:4])):
        f_payi=_f_payi3
elif(int(f_payi2[9][1:4])<int(f_payi3[10][1:4])):
    f_payi=f_payi2
else:
    f_payi=f_payi3
print(f_payi)
plt.title("time-paice")
plt.scatter(f_outt,f_q)
fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))
vert_bars = axes[0].barh(f_outt, f_q, color='#9999ff', align='center')
horiz_bars = axes[1].barh(f_outt, f_z, color='#ff9999', align='center')
#在水平或者垂直方向上画线
axes[0].axvline(0, color='gray', linewidth=2)
axes[1].axvline(0, color='gray', linewidth=2)
plt.rcParams['savefig.dpi'] = 500 #图片像素
plt.rcParams['figure.dpi'] = 500 #分辨率
plt.show()
# Out:
# ['东方航空MU5128', '波音 777-300ER(大型)', '21:05', '首都国际机场T2', '23:20', '虹桥国际机场T2', '准点率', '67%', '¥520起', '经济舱3.5折', '订票']
# ['海南航空HU7605', '波音 787-9(大型)', '07:45', '首都国际机场T1', '10:00', '虹桥国际机场T2', '准点率', '87%', '订立减¥3', '¥625起', '经济舱4.2折', '订票']
# ['东方航空MU5390', '空中客车 A320(中型)', '13:10', '首都国际机场T2', '经停', '洛阳', '18:10', '虹桥国际机场T2', '准点率', '90%', '¥570起', '经济舱3.9折', '订票']
# ['东方航空MU5128', '波音 777-300ER(大型)', '21:05', '首都国际机场T2', '23:20', '虹桥国际机场T2', '准点率', '67%', '¥520起', '经济舱3.5折', '订票']

# %%
#携程并没有提供关于城市与城市字母缩写的关联，所以通过本程序获取，为上程序提供用户交互的基础
#本程序通过webdriver控制浏览器获取携程的城市字母缩写


from time import sleep, strftime
from random import randint
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import smtplib
from email.mime.multipart import MIMEMultipart

#打开chrome
chromedriver_path = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe'
driver = webdriver.Chrome(executable_path=chromedriver_path) 
#随便打开一个机票查询的网页
kayakURL='https://flights.ctrip.com/itinerary/roundtrip/bjs-sha?date=2019-07-03,2019-07-18'
driver.get(kayakURL)
#睡眠防止网速太慢导致无法读取到元素
sleep(randint(4,5))
#三次循环分别对应：ABCD的字母大引索框，ABCD的字母小引索框，每个首字母的所有城市
for awww in range(2,7):
    for aww in range(1,10):
        for aw in range(1,30):
            try:
                caa='//*[@id="dcity0"]'#输入框的id
                driver.find_element_by_xpath(caa).click()
                cheap_paice='//*[@id="address_hot"]/div[2]/ol/li['+str(awww)+']/span'
                driver.find_element_by_xpath(cheap_paice).click()
                aaa='//*[@id="address_hot"]/div[2]/dl/div['+str(aww)+']/dd/a['+str(aw)+']'
                driver.find_element_by_xpath(aaa).click()
                awe='//*[@id="dcity0"]'
                awe2=driver.find_element_by_xpath(awe)
                print(awe2.get_attribute("value"))
                sleep(1)
            except:
                pass
# Out:
# 阿勒泰(AAT)
# 阿克苏(AKU)
# 鞍山(AOG)
# 安庆(AQG)
# 安顺(AVA)
# 阿拉善左旗(AXF)
# 澳门(MFM)
# 阿里(NGQ)
# 阿拉善右旗(RHT)
# 阿尔山(YIE)
# 巴中(BZX)
# 百色(AEB)
# 包头(BAV)
# 毕节(BFJ)
# 北海(BHY)
# 北京(BJS)
# 北京(南苑机场)(NAY)
# 北京(首都国际机场)(PEK)
# 博乐(BPL)
# 保山(BSD)
# 白城(DBC)
# 布尔津(KJI)
# 白山(NBS)
# 巴彦淖尔(RLK)
# 昌都(BPX)
# 承德(CDE)
# 常德(CGD)
# 长春(CGQ)
# 朝阳(CHG)
# 赤峰(CIF)
# 长治(CIH)
# 重庆(CKG)
# 长沙(CSX)
# 成都(CTU)
# 沧源(CWJ)
# 常州(CZX)
# 池州(JUH)
# 潮州(SWA)
# 潮汕(SWA)
# 大同(DAT)
# 达县(DAX)
# 达州(DAX)
# 稻城(DCY)
# 丹东(DDG)
# 迪庆(DIG)
# 大连(DLC)
# 大理(DLU)
# 敦煌(DNH)
# 东营(DOY)
# 大庆(DQA)
# 德令哈(HXD)
# 德宏(LUM)
# 鄂尔多斯(DSN)
# 额济纳旗(EJN)
# 恩施(ENH)
# 二连浩特(ERL)
# 福州(FOC)
# 阜阳(FUG)
# 抚远(FYJ)
# 富蕴(FYN)
# 广州(CAN)
# 果洛(GMQ)
# 格尔木(GOQ)
# 广元(GYS)
# 固原(GYU)
# 高雄(KHH)
# 赣州(KOW)
# 贵阳(KWE)
# 桂林(KWL)
# 红原(AHJ)
# 海口(HAK)
# 河池(HCJ)
# 邯郸(HDG)
# 黑河(HEK)
# 呼和浩特(HET)
# 合肥(HFE)
# 杭州(HGH)
# 淮安(HIA)
# 怀化(HJJ)
# 海拉尔(HLD)
# 哈密(HMI)
# 衡阳(HNY)
# 哈尔滨(HRB)
# 和田(HTN)
# 花土沟(HTT)
# 花莲(HUN)
# 霍林郭勒(HUO)
# 惠阳(HUZ)
# 惠州(HUZ)
# 汉中(HZG)
# 黄山(TXN)
# 呼伦贝尔(XRQ)
# 嘉义(CYI)
# 景德镇(JDZ)
# 加格达奇(JGD)
# ...
